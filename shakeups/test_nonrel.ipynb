# %%
import sys
import os 

repo_path = "D:\\photoionization_analysis"
sys.path.append(repo_path)


from fortran_output_analysis.nonrel.common_utility import Hole



hole = Hole("Krypton", 1, 4)

print(hole.binding_energy)


hole.load_binding_energy("test_energies.dat")


hole.binding_energy
# Out:
# None
# 0.5144760128515715

# %%
from fortran_output_analysis.global_utility import l_to_int

data_files = {("s", 0): "alsdlfls", ("p", 1): "ss", ("d", 2): "asdsdass"}

type_l_keys = type(next(iter(data_files.keys()))[0])
if type_l_keys is str:
    data_files = {(l_to_int(key[0]), key[1]): value for key, value in data_files.items()}


data_files
# Out:
# {(0, 0): 'alsdlfls', (1, 1): 'ss', (2, 2): 'asdsdass'}
